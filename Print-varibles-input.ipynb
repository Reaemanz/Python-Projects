# %%
name = input("Enter your name: ")
Country = 'Uganda'
print(name, 'comes from ', Country)
# Out:
# Emmanuel comes from  Uganda

# %%
f'{name} comes from {Country}'
# Out:
# 'Emmanuel comes from Uganda'
