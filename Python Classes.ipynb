# %% [markdown]
# PYTHON CLASSES

# %%
# This is a simple Python script that defines a Person class with a greet method.
class Person:
    def greet(self):
        return "Hello!"

p = Person()
print(p.greet())  # Hello!
# Out:
# Hello!
