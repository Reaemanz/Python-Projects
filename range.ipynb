# %% [markdown]
# Range

# %%
for n in range(3):
 print("Python")
# Out:
# Python
# Python
# Python

# %%
for n in range(10, 20):
 print(n * n)
# Out:
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361
